# %%
import pandas as pd

# %%
asasa = read_csv("C:\Users\Chern\Desktop\Height of Male and Female by Country 2022.csv")
# Out:
#   Input In [2]
#     asasa = read_csv("C:\Users\Chern\Desktop\Height of Male and Female by Country 2022.csv")
#                                                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
asasa = pd.read_csv("C:/Users/Chern/Desktop/Height of Male and Female by Country 2022.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 asasa = pd.read_csv("C:/Users/Chern/Desktop/Height of Male and Female by Country 2022.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
asasaMale Height in Cm
# Out:
#   Input In [4]
#     asasaMale Height in Cm
#               ^
# SyntaxError: invalid syntax

# %%
print(asasa.dtypes)
# Out:
# Rank                     int64
# Country Name            object
# Male Height in Cm      float64
# Female Height in Cm    float64
# Male Height in Ft      float64
# Female Height in Ft    float64
# dtype: object

# %%
print(type(asasa))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
asasa.median()
# Out:
# C:\Users\Chern\AppData\Local\Temp/ipykernel_6004/1474426770.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   asasa.median()
# Rank                   100.00
# Male Height in Cm      173.53
# Female Height in Cm    160.62
# Male Height in Ft        5.69
# Female Height in Ft      5.27
# dtype: float64

# %%
asasa.plot()
# Out:
# <AxesSubplot:>

# %%
asasa.plot(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
asasa[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
asasa.boxplot(column=['Male Height in Cm', 'Female Height in Cm'])
# Out:
# <AxesSubplot:>

# %%
asasa.describe()
# Out:
#              Rank  Male Height in Cm  Female Height in Cm  Male Height in Ft  \
# count  199.000000         199.000000           199.000000         199.000000
# mean   100.000000         173.089045           160.942915           5.678794
# std     57.590508           4.949832             4.076377           0.162510
# min      1.000000         160.130000           150.910000           5.250000
# 25%     50.500000         169.490000           158.240000           5.560000
# 50%    100.000000         173.530000           160.620000           5.690000
# 75%    149.500000         176.510000           163.870000           5.790000
# max    199.000000         183.780000           170.360000           6.030000
#
#        Female Height in Ft
# count           199.000000
# mean              5.280402
# std               0.133870
# min               4.950000
# 25%               5.190000
# 50%               5.270000
# 75%               5.375000
# max               5.590000

# %%
asasa.groupby('Male Height in Cm')('Female Height in Cm').hist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3948/2182100085.py in <module>
# ----> 1 asasa.groupby('Male Height in Cm')('Female Height in Cm').hist
#
# NameError: name 'asasa' is not defined
