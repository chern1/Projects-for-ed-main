# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('BigBasket Products.csv', index_col = 'product')

# %% [markdown]
# # изучение

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27555 entries, Garlic Oil - Vegetarian Capsule 500 mg to United Dreams Go Far Deodorant
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   brand         27554 non-null  object
#  4   sale_price    27555 non-null  float64
#  5   market_price  27555 non-null  float64
#  6   type          27555 non-null  object
#  7   rating        18929 non-null  float64
#  8   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.1+ MB

# %%
df.head(10)
# Out:
#                                                     index  \
# product
# Garlic Oil - Vegetarian Capsule 500 mg                  1
# Water Bottle - Orange                                   2
# Brass Angle Deep - Plain, No.2                          3
# Cereal Flip Lid Container/Storage Jar - Assorte...      4
# Creme Soft Soap - For Hands & Body                      5
# Germ - Removal Multipurpose Wipes                       6
# Multani Mati                                            7
# Hand Sanitizer - 70% Alcohol Base                       8
# Biotin & Collagen Volumizing Hair Shampoo + Bio...      9
# Scrub Pad - Anti- Bacterial, Regular                   10
#
#                                                                   category  \
# product
# Garlic Oil - Vegetarian Capsule 500 mg                    Beauty & Hygiene
# Water Bottle - Orange                               Kitchen, Garden & Pets
# Brass Angle Deep - Plain, No.2                        Cleaning & Household
# ...

# %%
df.sample(10)
# Out:
#                                                     index  \
# product
# Pickle - Gongura                                     5001
# Tasties Khari - Maska 200 gm + bb Royal Tea - M...   1968
# Loofah/Sponge Scrubber/Body Bath  - Hangable, B...   8175
# White Radish - Sliced                               15689
# Coffee Sprinkles - Silky Hazelnut                   22479
# Neem Capsules                                       16113
# Glass Round Store Fresh Storage Container           26594
# Wasabi Coated Green Peas                              615
# Baby Oil With Fruit Extracts                          589
# Coconut - Organically Grown                          9459
#
#                                                                     category  \
# product
# Pickle - Gongura                                      Snacks & Branded Foods
# Tasties Khari - Maska 200 gm + bb Royal Tea - M...     Bakery, Cakes & Dairy
# ...

# %% [markdown]
# # обработка null

# %%
df.isna().sum()
# Out:
# index              0
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
df['rating'].fillna(df.groupby("category")['rating'].transform("mean"), inplace=True)

# %%
df.dropna(how = 'all', inplace = True)
df.drop_duplicates(inplace = True)

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:ylabel='product'>

# %% [markdown]
# # исследование

# %%
df['category'] = df['category'].astype('category')

# %%
sns.histplot(df.rating,kde=True)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='Count'>

# %%
w = df.pivot_table(values = 'rating', index=['category'], aggfunc=[np.mean], fill_value=0, dropna=False)
w
# Out:
#                               mean
#                             rating
# category
# Baby Care                 4.023790
# Bakery, Cakes & Dairy     3.911128
# Beauty & Hygiene          3.930655
# Beverages                 4.084858
# Cleaning & Household      3.956667
# Eggs, Meat & Fish         0.000000
# Foodgrains, Oil & Masala  4.062198
# Fruits & Vegetables       0.000000
# Gourmet & World Food      3.984410
# Kitchen, Garden & Pets    3.734715
# Snacks & Branded Foods    3.983313

# %%
sns.heatmap(y.corr(), cmap= sns.color_palette(palette="RdBu"),linewidths=0.5,annot=True)
# Out:
# <AxesSubplot:xlabel='None-None', ylabel='None-None'>

# %%
df['skidka'] = df['market_price'] - df['sale_price']

# %%
df[df['skidka'] != 0].pivot_table(values = 'rating', index=['category'],aggfunc={'rating': len}, fill_value=0)
# Out:
#                           rating
# category
# Baby Care                    221
# Bakery, Cakes & Dairy        421
# Beauty & Hygiene            4656
# Beverages                    393
# Cleaning & Household        1484
# Eggs, Meat & Fish            176
# Foodgrains, Oil & Masala    1602
# Fruits & Vegetables          543
# Gourmet & World Food        1895
# Kitchen, Garden & Pets      2774
# Snacks & Branded Foods      1064

# %%
t = q.merge(w, how='inner', on='category', suffixes=('so skid', 'bez skid'))
t
# Out:
# C:\Users\MAx\AppData\Local\Temp\ipykernel_15656\4045666568.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   t = q.merge(w, how='inner', on='category', suffixes=('so skid', 'bez skid'))
#                           rating  (mean, rating)
# category
# Baby Care                    182        4.023790
# Bakery, Cakes & Dairy        330        3.911128
# Beauty & Hygiene            3522        3.930655
# Beverages                    284        4.084858
# Cleaning & Household        1137        3.956667
# Eggs, Meat & Fish              0        0.000000
# Foodgrains, Oil & Masala    1232        4.062198
# Fruits & Vegetables            0        0.000000
# Gourmet & World Food         949        3.984410
# Kitchen, Garden & Pets      2110        3.734715
# Snacks & Branded Foods       871        3.983313

# %%
y = df.pivot_table(values = ['market_price', 'sale_price', 'skidka', 'rating'], index=['category', 'sub_category'], aggfunc=[np.mean], fill_value=0).sort_values(by=('mean', 'market_price'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 y = df.pivot_table(values = ['market_price', 'sale_price', 'skidka', 'rating'], index=['category', 'sub_category'], aggfunc=[np.mean], fill_value=0).sort_values(by=('mean', 'market_price'))
#
# NameError: name 'df' is not defined

# %%
y['%'] = (y[('mean', 'skidka')]) / (y[('mean', 'market_price')])

# %%
y.sort_values(by=('%'), ascending=False)
# Out:
#                                                         mean            \
#                                                 market_price    rating
# category               sub_category
# Gourmet & World Food   Mutton & Lamb             1070.000000  3.984410
# Kitchen, Garden & Pets Bakeware                   360.312500  3.557956
#                        Steel Utensils             689.781870  3.590807
#                        Appliances & Electricals   418.391304  3.750623
# Cleaning & Household   Pooja Needs                198.837302  3.882421
# ...                                                      ...       ...
# Baby Care              Atta, Flours & Sooji       300.000000  3.600000
#                        Feeding & Nursing          268.583333  3.807636
# Eggs, Meat & Fish      Pork & Other Meats         263.000000  0.000000
# Baby Care              Baby Accessories           409.648649  3.333457
# Kitchen, Garden & Pets Gardening                  290.125000  3.627807
#
# ...
